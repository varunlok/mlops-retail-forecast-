# %% [markdown]
# <a href="https://colab.research.google.com/github/varunlok/mlops-retail-forecast-/blob/main/Lab1_Model_Training_and_Tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
